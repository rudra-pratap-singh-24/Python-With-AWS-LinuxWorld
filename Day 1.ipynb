# %% [markdown]
# ## Output

# %%
print (" Hello All ")
# Out:
#  Hello All

# %%
name= "Rudra"

# %%
print (name)
# Out:
# Rudra

# %%
print ("name")
# Out:
# name

# %% [markdown]
# ## Type method

# %%
type(name)
# Out:
# str

# %%
EXP= 7

# %%
print (EXP)
# Out:
# 7

# %%
type(EXP)
# Out:
# int

# %% [markdown]
# ## Data Types

# %%
pi= 3.16

# %%
print (pi)
# Out:
# 3.16

# %%
type(pi)
# Out:
# float

# %%
present= True

# %%
type(present)
# Out:
# bool

# %%
name= input("Enter your name.")
# Out:
# Enter your name. Rudra

# %%
print(name)
# Out:
# Rudra

# %%
type(name)
# Out:
# str

# %%
age= int(input("Enter your age"))
# Out:
# Enter your age 20

# %%
print(age)
# Out:
# 20

# %%
type(age)
# Out:
# int

# %%
print ("Loading ", end="/")
print (". ", end="/")
# Out:
# Loading /. /

# %%
print ("A", "B")
# Out:
# A B

# %% [markdown]
# ## Comment

# %%
# Hii I am Rudra

"""
Hii 
Guys
How 
are you

"""
# Out:
# '\nHii \nGuys\nHow \nare you\n\n'

# %% [markdown]
# ## Arithematic Operator

# %%
a= 10

# %%
b= 20

# %%
print (a+b)
# Out:
# 30

# %%
print(b-a)
# Out:
# 10

# %%
print (a*b)
# Out:
# 200

# %%
print (a/b)
# Out:
# 0.5

# %%
print (a%b)
# Out:
# 10

# %%
a= 5
b= 2
print (a ** b)
# Out:
# 25

# %% [markdown]
# ## Assignment Operator

# %%
X= 10

# %%
X+=5

# %%
print (X)
# Out:
# 15

# %%
y= 20

# %%
y-=10

# %%
print (y)
# Out:
# 10

# %% [markdown]
# ## Comparison Operator

# %%
a= 10

# %%
b= 20

# %%
print (a == b)
# Out:
# False

# %%
print (a > b)
# Out:
# False

# %%
print (b > a)
# Out:
# True

# %%
print (a >=b)
# Out:
# False

# %%
print (a<=b)
# Out:
# True

# %%
print (a!=b )
# Out:
# True

# %% [markdown]
# ## Logical Operator

# %%
age = 20

# %%
movie_ticket= False

# %%
print (age >18 and movie_ticket)
# Out:
# False

# %%
print (age >18 or movie_ticket)
# Out:
# True

# %% [markdown]
# ## Membership Operator

# %%
fruits= "apple"

# %%
print ("a" in fruits)
# Out:
# True

# %%
print ("z" in fruits)
# Out:
# False

# %% [markdown]
# ## Identity Operator

# %%
a= [1, 2, 3]

# %%
b=a

# %%
print (b)
# Out:
# [1, 2, 3]

# %%
c= [1, 2, 3]

# %%
print (a is b)
# Out:
# True

# %%
print (a is c)
# Out:
# False

# %%
print (a==c)
# Out:
# True

# %% [markdown]
# ## Bitwise Operator

# %%
a= 5

# %%
b= 3

# %% [raw]
# print (a & b)

# %%
print (a | b)
# Out:
# 7

# %%
print (a ^ b)
# Out:
# 6

# %% [markdown]
# ## String Operations

# %%
text= "Welcome to My World"

# %%
print (len(text))
# Out:
# 19

# %%
print (text.upper() )
# Out:
# WELCOME TO MY WORLD

# %%
print (text.lower() )
# Out:
# welcome to my world

# %%
print (text.title() )
# Out:
# Welcome To My World

# %%
print (text.strip() )
# Out:
# Welcome to My World

# %%
print (text.replace("My World", "Rudra") )
# Out:
# Welcome to Rudra

# %%
print (text.count("W"))
# Out:
# 2

# %%
print (text.find("to"))
# Out:
# 8

# %% [markdown]
# ## SLICING

# %%
WORD= "PYTHON"

# %%
print (WORD[0])
# Out:
# P

# %%
print (WORD[1])
# Out:
# Y

# %%
print (WORD[-1])
# Out:
# N

# %%
print (WORD[0:2])
# Out:
# PY

# %%
print (WORD[:])
# Out:
# PYTHON

# %%
print (WORD[2:])
# Out:
# THON

# %% [markdown]
# ## F String

# %%
name = "TOM"
age= 15

# %%
print (f"The name of student is {name}. The age of student is {age}" )
# Out:
# The name of student is TOM. The age of student is 15

# %%
Exp = 7

# %%
name = str("Jibbran")

# %%
a  = "hello"

# %%
b = "World"

# %%
a + b
# Out:
# 'helloWorld'

# %%
a + " " + b
# Out:
# 'hello World'

# %%
print ("MY name is " , name)
# Out:
# MY name is  Jibbran
